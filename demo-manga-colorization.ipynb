# %% [markdown]
# # Clone repo

# %%
# !git clone https://github.com/BinhPQ2/manga_read_along.git
# Out:
# Cloning into 'manga_read_along'...
# remote: Enumerating objects: 601, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 601 (delta 16), reused 53 (delta 15), pack-reused 544 (from 1)
# Receiving objects: 100% (601/601), 80.20 MiB | 41.79 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# %cd manga_read_along
# Out:
# /kaggle/working/manga_read_along

# %%
# !git submodule init
# !git submodule update --remote
# Out:
# Cloning into '/kaggle/working/manga_read_along/magi_functional'...
# Cloning into '/kaggle/working/manga_read_along/manga-colorization-v2-custom'...
# Submodule path 'magi_functional': checked out 'b3d050f8aa97e198180edac59b69209473befefc'
# Submodule path 'manga-colorization-v2-custom': checked out 'c261e7333ced98ff45a57cee62b7c04c2efa1a02'

# %%
# !pip install -q gdown

# %%
# !gdown 1qmxUEKADkEM4iYLp1fpPLLKnfZ6tcF-t -O /kaggle/working/manga_read_along/manga-colorization-v2-custom/networks/generator.zip
# !mkdir /kaggle/working/manga_read_along/manga-colorization-v2-custom/denoising/models
# !gdown 161oyQcYpdkVdw8gKz_MA8RD-Wtg9XDp3 -O /kaggle/working/manga_read_along/manga-colorization-v2-custom/denoising/models/net_rgb.pth
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1qmxUEKADkEM4iYLp1fpPLLKnfZ6tcF-t
# From (redirected): https://drive.google.com/uc?id=1qmxUEKADkEM4iYLp1fpPLLKnfZ6tcF-t&confirm=t&uuid=75fbf2c2-3c2f-4eba-8deb-7db98fefca00
# To: /kaggle/working/manga_read_along/manga-colorization-v2-custom/networks/generator.zip
# 100%|████████████████████████████████████████| 129M/129M [00:02<00:00, 45.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=161oyQcYpdkVdw8gKz_MA8RD-Wtg9XDp3
# To: /kaggle/working/manga_read_along/manga-colorization-v2-custom/denoising/models/net_rgb.pth
# 100%|███████████████████████████████████████| 3.44M/3.44M [00:00<00:00, 224MB/s]

# %%
# !pip install -q Pillow==9.5.0
# Out:
# Collecting Pillow==9.5.0
#   Downloading Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Downloading Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 40.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 10.3.0
#     Uninstalling pillow-10.3.0:
#       Successfully uninstalled pillow-10.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed Pillow-9.5.0

# %%
# !python "manga-colorization-v2-custom/inference_v2.py" -p "magi_functional/data_test/personal_data/Ruri_Dragon/raw/" -des_path "manga-colorization-v2-custom/denoising/models/net_rgb.pth" -gen "manga-colorization-v2-custom/networks/generator.zip" -s "./test_output_coloring" -ds 0 --gpu
# Out:
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/32.jpg
# Saved colorized image to: ./test_output_coloring/32.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/19.jpg
# Saved colorized image to: ./test_output_coloring/19.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/03.jpg
# Saved colorized image to: ./test_output_coloring/03.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/40.jpg
# Saved colorized image to: ./test_output_coloring/40.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/34.jpg
# Saved colorized image to: ./test_output_coloring/34.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/04.jpg
# Saved colorized image to: ./test_output_coloring/04.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/39.jpg
# Saved colorized image to: ./test_output_coloring/39.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/45.jpg
# Saved colorized image to: ./test_output_coloring/45.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/25.jpg
# Saved colorized image to: ./test_output_coloring/25.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/01.jpg
# Saved colorized image to: ./test_output_coloring/01.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/28.jpg
# Saved colorized image to: ./test_output_coloring/28.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/13.jpg
# Saved colorized image to: ./test_output_coloring/13.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/18.jpg
# Saved colorized image to: ./test_output_coloring/18.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/06.jpg
# Saved colorized image to: ./test_output_coloring/06.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/33.jpg
# Saved colorized image to: ./test_output_coloring/33.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/02.jpg
# Saved colorized image to: ./test_output_coloring/02.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/20.jpg
# Saved colorized image to: ./test_output_coloring/20.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/43.jpg
# Saved colorized image to: ./test_output_coloring/43.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/44.jpg
# Saved colorized image to: ./test_output_coloring/44.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/15.jpg
# Saved colorized image to: ./test_output_coloring/15.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/30.jpg
# Saved colorized image to: ./test_output_coloring/30.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/22.jpg
# Saved colorized image to: ./test_output_coloring/22.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/24.jpg
# Saved colorized image to: ./test_output_coloring/24.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/14.jpg
# Saved colorized image to: ./test_output_coloring/14.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/21.jpg
# Saved colorized image to: ./test_output_coloring/21.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/37.jpg
# Saved colorized image to: ./test_output_coloring/37.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/09.jpg
# Saved colorized image to: ./test_output_coloring/09.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/42.jpg
# Saved colorized image to: ./test_output_coloring/42.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/17.jpg
# Saved colorized image to: ./test_output_coloring/17.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/31.jpg
# Saved colorized image to: ./test_output_coloring/31.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/27.jpg
# Saved colorized image to: ./test_output_coloring/27.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/26.jpg
# Saved colorized image to: ./test_output_coloring/26.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/07.jpg
# Saved colorized image to: ./test_output_coloring/07.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/08.jpg
# Saved colorized image to: ./test_output_coloring/08.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/35.jpg
# Saved colorized image to: ./test_output_coloring/35.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/36.jpg
# Saved colorized image to: ./test_output_coloring/36.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/00.jpg
# Saved colorized image to: ./test_output_coloring/00.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/29.jpg
# Saved colorized image to: ./test_output_coloring/29.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/12.jpg
# Saved colorized image to: ./test_output_coloring/12.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/23.jpg
# Saved colorized image to: ./test_output_coloring/23.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/38.jpg
# Saved colorized image to: ./test_output_coloring/38.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/41.jpg
# Saved colorized image to: ./test_output_coloring/41.jpg
# Processing: magi_functional/data_test/personal_data/Ruri_Dragon/raw/11.jpg
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/manga_read_along/manga-colorization-v2-custom/inference_v2.py", line 90, in <module>
#     main()
#   File "/kaggle/working/manga_read_along/manga-colorization-v2-custom/inference_v2.py", line 67, in main
#     colorize_images(colorization_path, colorizer, args.path, args.size, args.denoiser, args.denoiser_sigma)
#   File "/kaggle/working/manga_read_along/manga-colorization-v2-custom/inference_v2.py", line 37, in colorize_images
#     colorize_single_image(file_path, save_path, colorizator, size, denoiser, denoiser_sigma)
#   File "/kaggle/working/manga_read_along/manga-colorization-v2-custom/inference_v2.py", line 20, in colorize_single_image
#     colorization = process_image(image, colorizator, size, denoiser, denoiser_sigma)
#   File "/kaggle/working/manga_read_along/manga-colorization-v2-custom/inference_v2.py", line 11, in process_image
#     colorizator.set_image(image, size, denoiser, denoiser_sigma)
#   File "/kaggle/working/manga_read_along/manga-colorization-v2-custom/colorizator.py", line 31, in set_image
#     image = self.denoiser.get_denoised_image(image, sigma=denoise_sigma)
#   File "/kaggle/working/manga_read_along/manga-colorization-v2-custom/denoising/denoiser.py", line 100, in get_denoised_image
#     return variable_to_cv2_image(outim)
#   File "/kaggle/working/manga_read_along/manga-colorization-v2-custom/denoising/utils.py", line 28, in variable_to_cv2_image
#     res = varim.data.cpu().numpy()[0]
# KeyboardInterrupt
